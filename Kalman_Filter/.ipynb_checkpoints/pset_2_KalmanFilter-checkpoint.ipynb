# %% [markdown]
# __Author(s): Chaojie Feng__<br/>
# __Github: https://github.com/fcjscott__<br/>
# __Collaborator(s): Individual__<br/>
# __External Resources: Kalman-and-Bayesian-Filter-in-Python__<br/>
# __Specific Contributions: ALL__<br/>
# __Aggregate Contributions: 100%__<br/>

# %% [markdown]
# # 1. System Definition
# You will consider a 2 wheeled robot similar to the one shown in Fig. 1. It has two wheels of radius r = 20mm,
# separated by a distance w = 85mm. It drags a tail for stability.
# Figure 1: Two wheeled tank-drive robot
# 1
# Each wheel is powered independently by a bi-directional continuous rotation servo—part number FS90R—with
# the angular velocity of the wheel controlled by a signal from the microcontroller. This allows the robot to drive
# forwards or backwards at variable speed, or turn with any turning radius. There may be slippage between the wheels
# and the floor; assume the resulting effective angular speed of the wheels is normal with a standard deviation of 5%
# of the max motor speed.
# The robot has two laser range sensors—part number VL53L0X—and an inertial measurement unit (IMU)—part
# number MPU-9250. The output of these sensors will be a function of the positional state of the robot within its
# environment.
# The robot will be driving within a rectangular environment of length L = 750mm and width W = 500mm,
# consisting of 4 walls bounding an open space.

# %% [markdown]
# # 2. Mathematical Setup
#
# The state of your robot will consist of the 3DOF pose of the robot in 2D space. You may also want to include
# velocity terms. In addition, your state may include a gyro bias term for greater accuracy. Thus, your robot state
# will have at least 3 variables, but may have more.
# Your control input will be the angular velocity values you prescribe for each wheel, for a total of 2 input variables.
# Your sensor output from the laser range sensors will consist of the distance to a wall in a straight line in front of the
# robot and the distance to a wall in a straight line to the right of the robot. The IMU will return an absolute bearing
# indicating the angle of the robot with respect to magnetic north, and can also return an angular rate measurement.
# We will ignore the accelerometer on the IMU. Thus the robot system will produce 3 or 4 output values.

# %% [markdown]
# ## 2.1 Define System Model
#
# Befor start building the system model, we need to define our constant variables:
#
# $$r = wheel \ radius = 20 \ mm$$
# $$d = wheel \ distance = 85 \ mm$$
#
#
#
# First of all, we want to design our state variables as well as system dynamics. We want to track the position of robot $(x,y)$ and the heading of robot $(h)$. That means we need 3 state variables $x$,$y$ and $h$:
#
# $$\mathbf x = \begin{bmatrix}x \\ y\\ \theta \end{bmatrix}$$
#
# and our input control parameter $u$ reprents input motor angular velocities for both left wheel and right wheel respectively:
#
# $$\mathbf u = \begin{bmatrix} u1 \\ u2 \end{bmatrix}$$
#
# We will thus model our real system with some noise as input:
#
# $$\bar x = f(x, u) + \mathcal{N}(0, Q)$$
# $$ u = u + \mathcal{N}(0,M) $$
#
# We will assign $Q$ and $M$ to denote covariance matrix of state and input
#
# Also, the dynamics of system can be characterized as:
#
# $$\bar{\begin{bmatrix}x\\y\\\theta \end{bmatrix}} = \begin{bmatrix}x\\y\\\theta \end{bmatrix} +
# \begin{bmatrix} \frac{1}2 \cos(\theta)(u_1+u_2)r \\
#  \frac{1}2 \sin(\theta)(u_1+u_2)r \\
# \frac{(u_1-u_0)r}d \end{bmatrix}\Delta t$$
#
# ## 2.2 Define Measurement Model
#
# The robot has two laser sensor measuring the position and one IMU sensor measuring the heading. The laser sensor will be installed to detect the distance from robot head to the wall as well as to detect the distance from robot right side to the wall. Based on the measurements, robot state $x$ and $y$ can be calculated. Also, heading measurement and bias can be retreived directly from sensor without converting. The measurement model, along with noise $w$ can be described as:
#
# $$\mathbf z = \begin{bmatrix} z_f\\z_r\\\theta\\b\end{bmatrix} = h(x) + w$$
#
# Where $h(x)$ can be defined as:
#
# $$ h(x) = \begin{bmatrix} \sqrt{(p_{fx} - x)^2 + (p_{fy} - y)^2}
# \\\sqrt{(p_{rx} - x)^2 + (p_{ry} - y)^2}
# \\ \theta \end{bmatrix} $$
#
# In this scenario, $p_{f}$ and $p_{r}$ are considered as landmarks which used to charactrize measurements.

# %%
from IPython.display import Image
Image("/Users/scott/Pictures/Monosnap/EE209_1.png")

# %% [markdown]
# ## 2.3 Define Kalman Filter
#
# The kalman filter model I choose to use is called Extended Kalman Filter (EKF). The Kalman Filter works only on linear equations, but when problem became complicated and nonlinear terms are involved (especially dealing with trigonometry calculations). EKF is a method to eliminate non-linearity at point of estimate. Two processes are considered non-linear. The first one is system dynamics and the second one is measurement model:
#
# $$\dot{x} = f(x,u) + w_x$$
# $$z = h(x) + w_z$$
#
# Both process update function $f(x,u)$ and $h(x)$ may involve various non-linear functions. To linearize them, we need to introduce Jacobian Matrix to calculate partial derivative of $f(x,u)$ and $h(x)$ for each state and input:
#
# $$ F = \frac{\partial{f(x,u)}}{\partial{x}}\biggr |_ {x_t,u_t}\\ $$
# $$ V = \frac{\partial{f(x,u)}}{\partial{u}}\biggr |_ {x_t,u_t}\\ $$
#
# $$ H = \frac{\partial{h(\bar{x})}}{\partial{x}}\biggr |_ {\bar{x_t}}\\ $$
#
# At certain time = $t$ (usually not every time step due to hardware implementation), we will activate our EKF to do state extimation, which can be divided into prediction update ($priori$), measurement and observation update ($posteriori$)
#
#
# ### 2.3.1 Priori
#
# Let's assume at time $t = t_s^- + Ndt$ (N = 1,2,3...) we will activate our EKF in our controller (We will definitely not activate for each time step due to time limitation and source limitation in our controller). Based on previous $posteriori$ state and system dynamics, we can predict $priori$ state as:
#
# $$ \bar{x} = f(\hat{x},u_t) $$
#
#
# Also, we can calculate the $priori$ covariance matrix $\bar{P}$:
#
# $$ \bar{P} = F\hat{P}F^T + VMV^T $$
#
# Where $\hat{x}$ and $\hat{P}$ are $posteriori$ state and covariance matrix. $\hat{x}$ is initially set to start state and $\hat{P}$ is initially set to $I$
#
# ### 2.3.2 Measurement
#
# After prediction our next state, we want to take measurement from our sensors based on our true state $x$:
#
# $$ z = h(x) + w $$
#
# We also want to measure our residual $y$ from our true measurement and our observation estimation $\bar{z}$:
#
# $$ \bar{z} = h(\bar{x}) $$
#
# Thus $y$ can be updated as:
#
# $$ y = z - \bar{z} $$
#
# ### 2.3.3 Posteriori
#
# We reach the final step of our EKF process. Based on measurement and prediction, we need to update our model so that probablistically the $posteriori$ state $\hat{x}$ will be more close our true state $x$, and our covariance matrix $\hat{P}$ will be smaller to $\bar{P}$. This is achieved by updating our Kalman Gain $K$, which can be treated as a weighted factor and shows how much does the EKF believe in
# system dynamic update ($priori$) or measurements:
#
# $$ K = \bar{P}H^T(H\bar{P}H^T + R)^{-1} $$
# $$ \hat{x} = \bar{x} + Ky $$
# $$ \hat{P} = (I-KH)\bar{P} $$
#
# After getting $posteriori$, we reach at at time $t = t_s^+$. We will continue to run our robot starting at next time step, $t = t_s + 1$. We will not activate our EKF untill $t = t_s + (N+1)dt$

# %%
import numpy as np
import sympy as sp
from math import tan,sin,cos,atan
from numpy.random import randn
from numpy.linalg import inv
import matplotlib.pyplot as plt
import matplotlib.patches as plot_patch
from matplotlib import animation
from IPython import display

class myRobot:
    def __init__(self,wheelRadius = 20, wheelDistance = 85, 
                 maxMotorSpeed = 2*np.pi, dt_update = 0.5, 
                 gyro_bias = 0.05, Length = 750, Width = 500):
        
        print("initializing state and input......")
        self.x = np.array([20,30,np.pi/4])
        self.u = np.array([0,0])

        # use symbolic term to initialize
        
        # system dynamics
        x,y,theta,u0,u1,r,d,time,bias= sp.symbols('x,y,theta,u0,u1,r,d,time,b')
        
        # sensor measurements
        pfx,pfy,prx,pry = sp.symbols('pfx,pfy,prx,pry')
        
        # initialize fixed parameter
        self.r = wheelRadius
        self.d = wheelDistance
        self.maxMotorSpeed = maxMotorSpeed
        self.motor_err = 0.05*self.maxMotorSpeed
        self.dt_update = dt_update
        self.L = Length
        self.W = Width
        
        
        self.std_laser = 30       # 30 mm standard deviation
        self.std_imu = np.pi/180        # 1 degree standard deviation
        self.gyro_bias = gyro_bias
        self.gyro_std = self.std_imu
        
        
        
        # compute jacobian of f and h in symbolic term
        self.f = sp.Matrix([[x+1/2*sp.cos(theta + 0.5*(u1-u0)*r/d)*(u0+u1)*r*time],
                          [y+1/2*sp.sin(theta + 0.5*(u1-u0)*r/d)*(u0+u1)*r*time],
                          [theta + (u1-u0)*r/d*time]])
        
        
        self.h = sp.Matrix([[sp.sqrt((pfx - x)**2 + (pfy - y)**2)],
                           [sp.sqrt((prx - x)**2 + (pry - y)**2)],
                           [theta]])
        
        
        
        
        # F is partial derivative of f over state x
        # V is partial derivative of f over input u
        # P is variance-covariance matrix
        # H is partial derivative of z over x
        # R is sensor noise variance - covariance matrix
        self.F = self.f.jacobian(sp.Matrix([x,y,theta]))
        self.V = self.f.jacobian(sp.Matrix([u0,u1]))
        
        #self.P = np.identity(3)
        self.P = np.array([[100,0,0],[0,100,0],[0,0,0.01]])
        
        self.H = self.h.jacobian(sp.Matrix([x,y,theta]))
        
        self.R = np.array([[self.std_laser**2,0,0],
                           [0,self.std_laser**2,0],
                           [0,0,self.std_imu**2]])
        
        
        # initialize jacobian matrix using symbolic term
        self.subs = {x: self.x[0], y: self.x[1], theta: self.x[2], 
                     u0: self.u[0], u1: self.u[1], r:self.r, d:self.d, 
                     time:self.dt_update}
        
        
        # save necessary parameters as instances for later update
        self.theta = theta
        self.u0 = u0
        self.u1 = u1
        self.sub_x = x
        self.sub_y = y
        self.prx = prx
        self.pry = pry
        self.pfx = pfx
        self.pfy = pfy
        
        # initialize counter
        self.ct = 0
        
        
    
    def predict(self,u):
        """
        Predict the state x as well as kalman gain and covariance matrix with input u
        
        Input:
        u: input control parameter specified as numpy(left_motor_speed, right_motor_speed)
        
        Update:
        x: state after move
        F: Jacobian matrix of state
        V: Jacobian matrix of input control parameters
        M: covariance matrix of input control parameter
        P: variance - covariance matrix
        """
        self.x[2] = self.normalize_angle(self.x[2])
        self.x = self.move(self.x,self.dt_update,u)
        self.x[2] = self.normalize_angle(self.x[2])
        # substitute parameter to Jacobian matrix F and V
        self.subs[self.theta] = self.x[2]
        self.subs[self.u0] = u[0]
        self.subs[self.u1] = u[1]
        
        # updates on F, V and M
        F = np.array(self.F.evalf(subs=self.subs)).astype(float)
        V = np.array(self.V.evalf(subs=self.subs)).astype(float)
        M = np.array([[(self.motor_err)**2, 0], 
                   [0, (self.motor_err)**2]])
        
        self.P = np.dot(F, self.P).dot(F.T) + np.dot(V, M).dot(V.T)
        
        self.ct += 1
        

    
    def move(self,x,dt,u):
        """
        Describe next state with input u, current state x and time increment dt
        
        Input: 
        x: state variable specified by numpy(xpos, ypos, heading, bias)
        u: input control parameter specified as numpy(left_motor_speed, right_motor_speed)
        dt: time increment
        
        Output:
        x: state after move

        """
        
        # check validity
        if any(u) > self.maxMotorSpeed:
            raise ValueError('motor velocity should not exceed maximum speed')

        # if x[0] > 750 or x[0] < 0 or x[1] > 500 or x[1] < 0:
            raise ValueError('robot is out of boundary')
            
        #if dt != self.dt_update:
         #   print("the robot is moving"

        
        
        # wheel's speeds and distances
        lws= u[0]*self.r
        rws = u[1]*self.r
        vel = 0.5*(lws+rws)
        lwd = lws*dt
        rwd = rws*dt

        # dynamic model 
        dx2 = (rwd-lwd)/self.d
        dx0 = cos(x[2]+dx2/2)*vel*dt
        dx1 = sin(x[2]+dx2/2)*vel*dt
        
        x_next = x+np.array((dx0,dx1,dx2))

        return x_next

    def measure(self,x,noise = False):
        """
        Take measurement from sensor to describe the state based on true state and error. It also
        output the landmarks to calculate distance
        
        Input: 
        x: state variable specified by numpy(xpos, ypos, heading)
        
        Output:
        z: measurements given by sensor
        landmark: boundary point where laser hits
        """
        z_e = np.zeros(3)
        if noise:
            z_e = np.sqrt(self.R).dot(randn(3))
            
            
        x[2] = self.normalize_angle(x[2])
        
            
        # get right laser states
        hr = x[2] - np.pi/2
        hr = self.normalize_angle(hr)
        xr = np.array([x[0], x[1], hr])
        
        # get laser measurement
        pf = self.reflection(x)
        pr = self.reflection(xr)
        landmark = [pf, pr]
        
        front_dist = np.sqrt((pf[0] - x[0])**2 + (pf[1] - x[1])**2)
        right_dist = np.sqrt((pr[0] - xr[0])**2 + (pr[1] - xr[1])**2)
        
        
            
        z = np.array([front_dist,right_dist,x[2]]) + z_e
    
        
        return z, landmark
    
    def residual(self,z):
        """
        Find the residual between measurement and belief
        
        Input: 
        z: measurements given by sensor
        
        Output:
        y: residual between measurement and belief
        """
        z[2] = self.normalize_angle(z[2])
        z_bar,_ = self.measure(self.x)
        y = z - z_bar
        y[2] = self.normalize_angle(y[2])
        
        return y
    
    def update(self,z,landmark):
        """
        Based on residual, by finding the kalman gain 
        update the state and variance - covariance matrix to posteriori
        
        Input:
        y: residual
        
        Update:
        K: Kalman gain
        P: posteriori variance - covariance matrix
        x: posteriori state
        """
        # substitute variable with values
        self.subs[self.theta] = self.x[2]
        self.subs[self.sub_x] = self.x[0]
        self.subs[self.sub_y] = self.x[1]
        self.subs[self.pfx] = landmark[0][0]
        self.subs[self.pfy] = landmark[0][1]
        self.subs[self.prx] = landmark[1][0]
        self.subs[self.pry] = landmark[1][1]
        
        
        # Update kalman gain and state estimates
        H = np.array(self.H.evalf(subs = self.subs)).astype(float)
        y = self.residual(z)
        K1 = np.dot(self.P,H.T)
        K2 = np.linalg.inv(np.dot(H,self.P).dot(H.T)+self.R)
        self.K = K1.dot(K2)
        self.x = self.x + self.K.dot(y)
        self.P = (np.eye(3)-self.K.dot(H)).dot(self.P)
        
        #print("\t-- EKF updated successfully......")
        

    def intersection(self,x,boundary):
        """
        Private Function: get intersection boundary as laser emits on boundary
        """
        if x[2] in [0.0, -np.pi/2, np.pi, np.pi/2]:
            raise Exception("special heading")
                
        x_b = boundary[0]
        y_b = boundary[1]
        y_temp = (x_b - x[0])*np.tan(x[2]) + x[1]
        x_temp = (y_b - x[1])/np.tan(x[2]) + x[0]
            
        if x_temp >= 0 and x_temp <= self.L:
            return np.array((x_temp, y_b))
        else: 
            return np.array((x_b, y_temp))
            
    def reflection(self,x):
        """
        Private Function: get reflection point to charactrize landmark point
        """
        if x[2] >= -np.pi and x[2] < -np.pi/2:
            if x[2] != -np.pi:
                boundary = [0, 0]
                point = self.intersection(x,boundary)
            else:
                point = [0, x[1]]
            
        if x[2] >= -np.pi/2 and x[2] < 0.0:
            if x[2] != -np.pi/2:
                boundary = [self.L, 0]
                point = self.intersection(x,boundary)
            else:
                point = [x[0], 0]
                    
        if x[2] >= 0.0 and x[2] < np.pi/2:
            if x[2] != 0.0:
                boundary = [self.L, self.W]
                point = self.intersection(x,boundary)
            else:
                point = [self.L, x[1]]
                    
        if x[2] >= np.pi/2 and x[2] < np.pi:
            if x[2] != np.pi/2:
                boundary = [0, self.W]
                point = self.intersection(x,boundary)
            else:
                point = [x[1], self.W]
                    
        return point
        
        
    def normalize_angle(self,angle):
        """
        Private Function: normalize angle into [-pi, pi)
        """
        angle = np.mod(angle, 2*np.pi)
        if angle >= np.pi:
            angle -= 2*np.pi
            
        return angle

# %% [markdown]
# # 3. Evaluation
#
# You should implement and debug your algorithms in a simulated environment. You can choose to get the control
# inputs from a human driver, or implement pre-programmed behavior.
# Within the simulation, you should implement models of your sensor and actuator response (especially including
# noise) to generate realistic sensor traces given the control inputs. Identify any numerical parameters that need to
# be set, and explain how you selected the values of those parameters. Generating these models may require finding
# information on hardware datasheets.

# %%
def simulation(myRobot,T, init = True, mode = 1, animation = True):
    
    """
    run simulation based on robot object passed in. Animation mode is set defaultly to be true
    
    Input:
    myRobot: robot object with EKF updating method passed in
    T: total simulation time
    animation: bool variable indicates activation of frame-by-frame animation
    
    Output:
    None
    """
    
    
    # initialize movement updating interval and input parameter
    dt = 0.1
    u = np.array((2*np.pi,2*np.pi))
    
    # initialize Scott as my robot
    Scott = myRobot()
    dt_update = Scott.dt_update
    step = dt_update/dt
    x = np.array([40,40,np.pi/4])
    if init:
        Scott.x = x
    
    if not init:
        Scott.x = x + np.sqrt(Scott.R).dot(randn(3))
        Scott.P = Scott.R
        if not mode:
            Scott.x = x + 3*np.sqrt(Scott.R).dot(randn(3))
            Scott.P = np.array([[100,0,0],[0,100,0],[0,0,0.1]])
            
            
    e = Scott.motor_err
    
    x_traj = []
    y_traj = []
    x_priori = []
    y_priori = []
    x_post = []
    y_post = []
    x_measure = []
    y_measure = []
    
    
    for i in range(1,int(T/dt)+1):
        
        # simulate for different speed
        if i >= 10:
            u = np.array((3,1))
        if i >= 20:
            u = np.array((6,6))
        if i >= 40:
            u = np.array((2,4))
        if i >= 50:
            u = np.array([3,2])

        # make actual movement
        u_actual = u + e*randn(2)
        x = Scott.move(x,dt,u_actual)
        x_traj.append(x[0])
        y_traj.append(x[1])
        
        # activate EKF for every step
        if i % step == 0:
            
            # make prediction (priori)
            Scott.predict(u)
            print("--- Priori P ---")
            print(np.diag(Scott.P))
            
            # make observation (measurement)
            z,landmark = Scott.measure(x,noise = True)
            
            # make correction (posteriori)
            Scott.update(z,landmark)
            x_post.append(Scott.x[0])
            y_post.append(Scott.x[1])
            print("--- Posteriori P ---")
            print(np.diag(Scott.P))

            
           
        if animation: 
            # plot animated graph if animation is activated
            plt.figure(figsize = (20,15))
            plt.title("Time = %.2f s" % (i*dt_update),fontsize = 18)
            plt.grid(True)
            plt.xlim((0,750))
            plt.ylim((0,500))
            plt.plot(x_traj,y_traj,marker = '*') 
            plt.plot(x_post,y_post, marker = 'd')
            plt.legend(['trajectory','measurements','EKF estimates'],fontsize = 14)
            plt.show()
            display.clear_output(wait=True)
            
            
    if not animation:
        plt.figure(figsize = (20,15))
        plt.grid(True)
        plt.xlim((0,750))
        plt.ylim((0,500))
        plt.plot(x_traj,y_traj,marker = '*') 
        plt.plot(x_post,y_post, marker = 'd')
        plt.legend(['trajectory','EKF estimates'],fontsize = 14)

# %% [markdown]
# ## 3.1 Simulation and Experiments

# %% [markdown]
# ### 3.1.1 Implementation Parameters
# The realistic hardware encounters noises and bias. We also care about sampling rate since they are not analog devices. The laser sensor model VL53L0X from STMicrotronics uses ToF laser ranging module to provide accurate distance measurement. According to datasheet provided from STMicrotronics, the standard deviation for different environment (i.e. indoor/outdoor, whight target/grey target, etc) is different. Averagely, $\sigma = 5\%$ of measured distance. Based on our (750 X 500) dimension of environment, a $30 \ mm$ standard deviation of laser measurement is reasonable. The IMU, MPU-5290, on the other hand, has a standard deviation of absolute bearing $0.1 rad$. Finally, the motor will have a standard deviation of 5% of maximum motor speed.
#
# ### 3.1.2  Evaluation
# In order to generalize the effectiveness of our estimator, I tried to incorporate as many motions as possible including turining, high speed, low speed and "S" curve movement. First, we are going to analyze EKF with known initial state. By set ```init = True```, we can set initial location of our estimate to be true location at start stage, as followings:

# %%
# Evaluation with known initial state
simulation(myRobot,10,init = True, mode = 1, animation = False)
# Out:
# initializing state and input......
# --- Priori P ---
# [1.27599501e+02 1.27599501e+02 1.27320704e-02]
# --- Posteriori P ---
# [9.25436986e+01 9.23842684e+01 2.97150655e-04]
# --- Priori P ---
# [9.72463239e+01 9.44307564e+01 3.02922108e-03]
# --- Posteriori P ---
# [8.59357803e+01 8.57816502e+01 2.76741578e-04]
# --- Priori P ---
# [9.06790123e+01 8.74285349e+01 3.00881200e-03]
# --- Posteriori P ---
# [8.17817274e+01 7.91501909e+01 2.76576336e-04]
# --- Priori P ---
# [8.84004819e+01 8.89419713e+01 3.00864676e-03]
# --- Posteriori P ---
# [7.84065105e+01 7.42274841e+01 2.76324977e-04]
# --- Priori P ---
# [8.44358101e+01 8.58260346e+01 3.00839540e-03]
# --- Posteriori P ---
# [7.61145268e+01 6.95567887e+01 2.76286107e-04]
# --- Priori P ---
# [8.17921260e+01 8.16413745e+01 3.00835653e-03]
# --- Posteriori P ---
# [7.42923346e+01 6.55049177e+01 2.76273539e-04]
# --- Priori P ---
# [7.98902272e+01 7.76926301e+01 3.00834396e-03]
# --- Posteriori P ---
# [7.27075368e+01 6.20759618e+01 2.76270047e-04]
# --- Priori P ---
# [7.67744106e+01 6.65570272e+01 3.00834047e-03]
# --- Posteriori P ---
# [6.93515610e+01 6.04096836e+01 2.76507806e-04]
# --- Priori P ---
# [7.32820406e+01 6.46574751e+01 3.00857823e-03]
# --- Posteriori P ---
# [6.61931947e+01 5.92204170e+01 2.76523202e-04]
# --- Priori P ---
# [7.08274447e+01 6.17853225e+01 3.00859362e-03]
# --- Posteriori P ---
# [6.51909089e+01 5.63210996e+01 2.76550787e-04]
# --- Priori P ---
# [6.94276449e+01 5.92571887e+01 3.00862121e-03]
# --- Posteriori P ---
# [6.37441261e+01 5.43299655e+01 2.76551545e-04]
# --- Priori P ---
# [6.82995435e+01 5.69450987e+01 3.00862197e-03]
# --- Posteriori P ---
# [6.29981014e+01 5.20684312e+01 2.76551116e-04]
# --- Priori P ---
# [6.78214883e+01 5.44127614e+01 3.00862154e-03]
# --- Posteriori P ---
# [6.28183957e+01 4.95921587e+01 2.76551277e-04]
# --- Priori P ---
# [6.77159121e+01 5.18666044e+01 3.00862170e-03]
# --- Posteriori P ---
# [6.28303837e+01 4.72426247e+01 2.76551011e-04]
# --- Priori P ---
# [6.77637676e+01 4.94821358e+01 3.00862143e-03]
# --- Posteriori P ---
# [6.29401624e+01 4.50572063e+01 2.76550990e-04]
# --- Priori P ---
# [6.78504271e+01 4.73192418e+01 3.00862141e-03]
# --- Posteriori P ---
# [6.30554163e+01 4.30957470e+01 2.76550936e-04]
# --- Priori P ---
# [6.78947586e+01 4.54296290e+01 3.00862136e-03]
# --- Posteriori P ---
# [6.31233592e+01 4.14176384e+01 2.76550815e-04]
# --- Priori P ---
# [6.78303863e+01 4.38837612e+01 3.00862124e-03]
# --- Posteriori P ---
# [6.30488923e+01 4.00818163e+01 2.76550904e-04]
# --- Priori P ---
# [6.75188558e+01 4.27838101e+01 3.00862133e-03]
# --- Posteriori P ---
# [6.26625789e+01 3.92192429e+01 2.76551264e-04]
# --- Priori P ---
# [6.69207790e+01 4.21342424e+01 3.00862169e-03]
# --- Posteriori P ---
# [6.20613801e+01 3.87416517e+01 2.76551490e-04]

# %% [markdown]
# Note that as we know the initial state, our initial variance - covariance matrix can be set to a relative small value as we are confident that our initial state is close to actual stae. From the above figure and $priori$, $posteriori$ P, We can see that with known initial state, the robot's EKF is likely to converge, but it will not converge to an optimal condition with $P = 0$. $P$ will definitely get smaller from $priori$ to $posteriori$, however, it is not gaurantee that $P$ will go smaller from step to step. This phenomenon is especially apparent in unknown initial position case.

# %% [markdown]
# Next, we will evaluate our EKF with unknown initial condition. We will make a little modification to our initial $P$ so that we provide a greater range of confidence interval of our initial state. We will set our initial covariance matrix the same as our measurement covariance matrix $R$ and we assume our belief of initial state is within the ellipse area bounded by $R$:
# ```
# if not init:
#     Scott.x = x + np.sqrt(Scott.R).dot(randn(3))
#     Scott.P = Scott.R
# ```

# %%
# Evaluation with known initial state
simulation(myRobot,10,init = False, mode = 1, animation = False)
# Out:
# initializing state and input......
# --- Priori P ---
# [9.08438876e+02 9.08484289e+02 3.03668784e-03]
# --- Posteriori P ---
# [5.18792253e+02 3.98963390e+02 2.76685770e-04]
# --- Priori P ---
# [5.23522508e+02 4.00667379e+02 3.00875619e-03]
# --- Posteriori P ---
# [3.06736945e+02 2.96414984e+02 2.76586981e-04]
# --- Priori P ---
# [3.11469252e+02 2.98001746e+02 3.00865740e-03]
# --- Posteriori P ---
# [2.26781584e+02 2.27450157e+02 2.76582963e-04]
# --- Priori P ---
# [2.32876450e+02 2.37648157e+02 3.00865339e-03]
# --- Posteriori P ---
# [1.84310959e+02 1.82200645e+02 2.76356752e-04]
# --- Priori P ---
# [1.90143335e+02 1.93752430e+02 3.00842717e-03]
# --- Posteriori P ---
# [1.56969032e+02 1.51734243e+02 2.76318165e-04]
# --- Priori P ---
# [1.62657609e+02 1.63589305e+02 3.00838859e-03]
# --- Posteriori P ---
# [1.37787840e+02 1.30172889e+02 2.76303788e-04]
# --- Priori P ---
# [1.43639859e+02 1.41926592e+02 3.00837421e-03]
# --- Posteriori P ---
# [1.23201874e+02 1.14598364e+02 2.76295381e-04]
# --- Priori P ---
# [1.27199621e+02 1.19087514e+02 3.00836580e-03]
# --- Posteriori P ---
# [1.09620986e+02 1.04407917e+02 2.76514656e-04]
# --- Priori P ---
# [1.13542519e+02 1.08631958e+02 3.00858508e-03]
# --- Posteriori P ---
# [9.95135342e+01 9.58795444e+01 2.76528951e-04]
# --- Priori P ---
# [1.04229076e+02 9.83325022e+01 3.00859937e-03]
# --- Posteriori P ---
# [9.33120534e+01 8.70564921e+01 2.76552638e-04]
# --- Priori P ---
# [9.77289050e+01 8.97965347e+01 3.00862306e-03]
# --- Posteriori P ---
# [8.77086894e+01 8.03494169e+01 2.76553614e-04]
# --- Priori P ---
# [9.22502187e+01 8.29674261e+01 3.00862404e-03]
# --- Posteriori P ---
# [8.30920206e+01 7.47505132e+01 2.76553526e-04]
# --- Priori P ---
# [8.78196555e+01 7.71837325e+01 3.00862395e-03]
# --- Posteriori P ---
# [7.95811653e+01 6.97103315e+01 2.76553201e-04]
# --- Priori P ---
# [8.44566786e+01 7.19965879e+01 3.00862362e-03]
# --- Posteriori P ---
# [7.69989063e+01 6.50577159e+01 2.76552813e-04]
# --- Priori P ---
# [8.19304062e+01 6.72900411e+01 3.00862324e-03]
# --- Posteriori P ---
# [7.49945318e+01 6.08892341e+01 2.76552455e-04]
# --- Priori P ---
# [7.99293037e+01 6.31218808e+01 3.00862288e-03]
# --- Posteriori P ---
# [7.33741716e+01 5.71920092e+01 2.76551725e-04]
# --- Priori P ---
# [7.82762067e+01 5.94572150e+01 3.00862215e-03]
# --- Posteriori P ---
# [7.19856161e+01 5.39752146e+01 2.76551454e-04]
# --- Priori P ---
# [7.67776353e+01 5.63503184e+01 3.00862188e-03]
# --- Posteriori P ---
# [7.06715397e+01 5.12885156e+01 2.76551337e-04]
# --- Priori P ---
# [7.52294097e+01 5.38967929e+01 3.00862176e-03]
# --- Posteriori P ---
# [6.91952467e+01 4.92614837e+01 2.76551128e-04]
# --- Priori P ---
# [7.34779888e+01 5.21458276e+01 3.00862155e-03]
# --- Posteriori P ---
# [6.74382441e+01 4.79234099e+01 2.76550751e-04]

# %% [markdown]
# Clearly, our EKF still provides a good estimation of our true state. This is also verified by variance - covariance matrix, as variances are decreased after each update. What if our initial covariance matrix is not designed well ? In this case, we will set our ```mode = 0``` so that
# ```
#  if not init:
#     Scott.x = x + np.sqrt(Scott.R).dot(randn(3))
#     Scott.P = Scott.R
#     if not mode:
#         Scott.x = x + 3*np.sqrt(Scott.R).dot(randn(3))
#         Scott.P = np.array([[100,0,0],[0,100,0],[0,0,0.1]])
# ```
# We set our initial $P$ to be much smaller than our $R$ and run our simulation as following:

# %%
# Evaluation with known initial state
simulation(myRobot,10,init = False, mode = 0, animation = False)
# Out:
# initializing state and input......
# --- Priori P ---
# [3.15503528e+02 2.95001232e+02 1.02732070e-01]
# --- Posteriori P ---
# [8.84177600e+01 9.75544922e+01 3.03607876e-04]
# --- Priori P ---
# [9.31829770e+01 9.96009851e+01 3.03567830e-03]
# --- Posteriori P ---
# [8.09473700e+01 9.37542974e+01 2.76825096e-04]
# --- Priori P ---
# [8.57704741e+01 9.53393653e+01 3.00889552e-03]
# --- Posteriori P ---
# [7.39487059e+01 9.18058520e+01 2.76604673e-04]
# --- Priori P ---
# [7.99786785e+01 1.02246084e+02 3.00867510e-03]
# --- Posteriori P ---
# [6.84146621e+01 8.98904945e+01 2.76417559e-04]
# --- Priori P ---
# [7.39665713e+01 1.02020150e+02 3.00848798e-03]
# --- Posteriori P ---
# [6.50329293e+01 8.67602002e+01 2.76384743e-04]
# --- Priori P ---
# [7.02407985e+01 9.93445385e+01 3.00845517e-03]
# --- Posteriori P ---
# [6.29508977e+01 8.31204017e+01 2.76377132e-04]
# --- Priori P ---
# [6.82026345e+01 9.56762783e+01 3.00844755e-03]
# --- Posteriori P ---
# [6.16881929e+01 7.92342925e+01 2.76342608e-04]
# --- Priori P ---
# [6.58956840e+01 8.35733405e+01 3.00841303e-03]
# --- Posteriori P ---
# [5.89592715e+01 7.71370148e+01 2.76515846e-04]
# --- Priori P ---
# [6.30881450e+01 8.11857552e+01 3.00858627e-03]
# --- Posteriori P ---
# [5.65049385e+01 7.52017225e+01 2.76528576e-04]
# --- Priori P ---
# [6.12691190e+01 7.76448614e+01 3.00859900e-03]
# --- Posteriori P ---
# [5.60187401e+01 7.14704569e+01 2.76566620e-04]
# --- Priori P ---
# [6.04370669e+01 7.42272002e+01 3.00863704e-03]
# --- Posteriori P ---
# [5.51908433e+01 6.87040318e+01 2.76562915e-04]
# --- Priori P ---
# [5.98085470e+01 7.12597357e+01 3.00863334e-03]
# --- Posteriori P ---
# [5.49151931e+01 6.58393676e+01 2.76560705e-04]
# --- Priori P ---
# [5.97492285e+01 6.81752007e+01 3.00863113e-03]
# --- Posteriori P ---
# [5.53414514e+01 6.25928270e+01 2.76558491e-04]
# --- Priori P ---
# [6.02720006e+01 6.48302403e+01 3.00862891e-03]
# --- Posteriori P ---
# [5.61511151e+01 5.92022049e+01 2.76556905e-04]
# --- Priori P ---
# [6.10397154e+01 6.14793995e+01 3.00862733e-03]
# --- Posteriori P ---
# [5.69982882e+01 5.59852000e+01 2.76555537e-04]
# --- Priori P ---
# [6.17475511e+01 5.84029145e+01 3.00862596e-03]
# --- Posteriori P ---
# [5.76478448e+01 5.31543449e+01 2.76552510e-04]
# --- Priori P ---
# [6.22326396e+01 5.57373499e+01 3.00862293e-03]
# --- Posteriori P ---
# [5.79752657e+01 5.08561927e+01 2.76549297e-04]
# --- Priori P ---
# [6.23967329e+01 5.36029751e+01 3.00861972e-03]
# --- Posteriori P ---
# [5.79147467e+01 4.91640408e+01 2.76546609e-04]
# --- Priori P ---
# [6.19005756e+01 5.23415193e+01 3.00861703e-03]
# --- Posteriori P ---
# [5.69347209e+01 4.86214441e+01 2.76540952e-04]
# --- Priori P ---
# [6.05294397e+01 5.21893070e+01 3.00861137e-03]
# --- Posteriori P ---
# [5.52501954e+01 4.91106264e+01 2.76534467e-04]

# %% [markdown]
# Clearly, although the variance - covariance matrix is converging within each step, the estimator is not converging to a reasonable estimates of true state, and this is the limitation of Extended Kalman Filter. If an EKF is going to be implemented in the system, a good estimates of initial state is very important. Another method to deal with this issue is to implement Unscented Kalman Filter.
